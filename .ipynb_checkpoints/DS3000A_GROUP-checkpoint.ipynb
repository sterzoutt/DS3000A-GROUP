# %% [markdown]
# <a href="https://colab.research.google.com/github/sterzoutt/DS3000A-GROUP/blob/main/DS3000A_GROUP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.decomposition import PCA

from xgboost import XGBClassifier

import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.nn.functional as F
import torch.nn.utils as utils

df = pd.read_csv("diabetes_dataset.csv");
display(df.head())
display(df.shape)
# Out:
#    age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   48  Female     White      Highschool        Middle          Employed
# 2   60    Male  Hispanic      Highschool        Middle        Unemployed
# 3   74  Female     Black      Highschool           Low           Retired
# 4   46    Male     White        Graduate        Middle           Retired
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             0
# 1         Former                             1
# 2          Never                             1
# 3          Never                             0
# 4          Never                             1
#
#    physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                 215         5.7  ...               41
# 1                                 143         6.7  ...               55
# 2                                  57         6.4  ...               66
# 3                                  49         3.4  ...               50
# 4                                 109         7.2  ...               52
#
#    ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0              160            145              136                   236
# 1               50             30               93                   150
# 2               99             36              118                   195
# 3               79            140              139                   253
# 4              125            160              137                   184
#
#    insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0           6.36   8.18                 29.6          Type 2
# 1           2.00   5.63                 23.0     No Diabetes
# 2           5.07   7.51                 44.7          Type 2
# 3           5.28   9.03                 38.2          Type 2
# 4          12.74   7.20                 23.5          Type 2
#
#    diagnosed_diabetes
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   1
#
# [5 rows x 31 columns]
# (100000, 31)

# %%
#Q1.2
#dataset has no null values to replace (good)
df.isnull().sum()
# Out:
# age                                   0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# employment_status                     0
# smoking_status                        0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# family_history_diabetes               0
# hypertension_history                  0
# cardiovascular_history                0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ldl_cholesterol                       0
# triglycerides                         0
# glucose_fasting                       0
# glucose_postprandial                  0
# insulin_level                         0
# hba1c                                 0
# diabetes_risk_score                   0
# diabetes_stage                        0
# diagnosed_diabetes                    0
# dtype: int64

# %%
df['diagnosed_diabetes'].value_counts(normalize = True)
df['diagnosed_diabetes'].value_counts(normalize = False)
# Out:
# diagnosed_diabetes
# 1    59998
# 0    40002
# Name: count, dtype: int64

# %%
X = df.drop('diagnosed_diabetes', axis=1)
y = df['diagnosed_diabetes']

# %%
display(y.value_counts(normalize=False))
display(y.value_counts(normalize=True))
# Out:
# diagnosed_diabetes
# 1    59998
# 0    40002
# Name: count, dtype: int64
# diagnosed_diabetes
# 1    0.59998
# 0    0.40002
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlations_with_target = df.corr(numeric_only=True)['diagnosed_diabetes'].drop('diagnosed_diabetes')

correlations_with_target = correlations_with_target.sort_values(ascending=False)

corr_df = correlations_with_target.to_frame(name='Correlation with Diagnosed Diabetes')

# %%
# initialize an empty list to store the new column order
ordered_columns = []

ordered_columns.append('diagnosed_diabetes')

# iterate through the original DataFrame columns
for col in df.columns:
    if col != 'diagnosed_diabetes':
        ordered_columns.append(col)

# new df with proper ordering
dfReady = df[ordered_columns]

display(dfReady.head())
# Out:
#    diagnosed_diabetes  age  gender ethnicity education_level  income_level  \
# 0                   1   58    Male     Asian      Highschool  Lower-Middle
# 1                   0   48  Female     White      Highschool        Middle
# 2                   1   60    Male  Hispanic      Highschool        Middle
# 3                   1   74  Female     Black      Highschool           Low
# 4                   1   46    Male     White        Graduate        Middle
#
#   employment_status smoking_status  alcohol_consumption_per_week  \
# 0          Employed          Never                             0
# 1          Employed         Former                             1
# 2        Unemployed          Never                             1
# 3           Retired          Never                             0
# 4           Retired          Never                             1
#
#    physical_activity_minutes_per_week  ...  cholesterol_total  \
# 0                                 215  ...                239
# 1                                 143  ...                116
# 2                                  57  ...                213
# 3                                  49  ...                171
# 4                                 109  ...                210
#
#    hdl_cholesterol  ldl_cholesterol  triglycerides  glucose_fasting  \
# 0               41              160            145              136
# 1               55               50             30               93
# 2               66               99             36              118
# 3               50               79            140              139
# 4               52              125            160              137
#
#    glucose_postprandial  insulin_level  hba1c  diabetes_risk_score  \
# 0                   236           6.36   8.18                 29.6
# 1                   150           2.00   5.63                 23.0
# 2                   195           5.07   7.51                 44.7
# 3                   253           5.28   9.03                 38.2
# 4                   184          12.74   7.20                 23.5
#
#    diabetes_stage
# 0          Type 2
# 1     No Diabetes
# 2          Type 2
# 3          Type 2
# 4          Type 2
#
# [5 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# calculate the full correlation matrix
correlationMatrix = dfReady.corr(numeric_only=True)

# set up the matplotlib figure
plt.figure(figsize=(18, 15)) # Adjust size for better readability

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlationMatrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Full Correlation Matrix of Features (including Diagnosed Diabetes)', fontsize=16)
plt.show()
